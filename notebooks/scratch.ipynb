# %%
import os
import sys
sys.path.append(os.path.abspath('../scripts'))
fig_path      = '../figures/'
data_path     = '../data/'

# %%
import netCDF4 as nc
import numpy as np
import xarray as xr
import warnings
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import pandas as pd 
import seaborn as sns
import cmocean as cmo
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
from proj_utils import *
from mapping_utils import *

# %% [markdown]
# ## (1) Pull WSC Fields

# %%
ds_wsc = xr.open_dataset(data_path + '/wsc.nc')
ds_wsc = rmv_clm(ds_wsc)
ds_wsc = seasonal_detrend(ds_wsc)

# %%
plt.contourf(ds_wsc.wsc[24,:,:]/1e6)
plt.colorbar()

# %%
levels = np.arange
# Out:
# <bound method DataArrayAggregations.max of <xarray.DataArray 'wsc' (time: 372, latitude: 241, longitude: 361)> Size: 259MB
# array([[[            nan,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         ...,
#         [            nan,             nan,             nan, ...,
#          -2.61817458e+04, -2.56452480e+04, -2.57168646e+04],
#         [            nan,             nan,             nan, ...,
#          -1.72119278e+04, -1.83713334e+04, -2.02457140e+04],
#         [            nan,             nan,             nan, ...,
#           2.84570335e+04,  4.38729525e+04,  7.72829480e+04]],
#
#        [[            nan,             nan,             nan, ...,
# ...

# %%
levels = np.arange(-5e7, 5.1e7, 51)
plt.contourf(ds_wsc.longitude, ds_wsc.latitude, ds_wsc.wsc[100,:,:],levels = levels)
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 levels = np.arange(-5e7, 5.1e7, 51)
# ----> 2 plt.contourf(ds_wsc.longitude, ds_wsc.latitude, ds_wsc.wsc[100,:,:],levels = levels)
#       3 plt.colorbar()
#
# File ~/gs-var-env/lib/python3.13/site-packages/matplotlib/pyplot.py:3190, in contourf(data, *args, **kwargs)
#    3188 @_copy_docstring_and_deprecators(Axes.contourf)
#    3189 def contourf(*args, data=None, **kwargs) -> QuadContourSet:
# -> 3190     __ret = gca().contourf(
#    3191         *args, **({"data": data} if data is not None else {}), **kwargs
#    3192     )
#    3193     if __ret._A is not None:  # type: ignore[attr-defined]
#    3194         sci(__ret)
#
# File ~/gs-var-env/lib/python3.13/site-packages/matplotlib/__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
# ...
