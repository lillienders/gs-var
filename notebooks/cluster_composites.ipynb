# %%
import os
import sys
sys.path.append(os.path.abspath('../scripts'))
fig_path      = '../figures/'
data_path     = '../data/'

# %%
import netCDF4 as nc
import numpy as np
import xarray as xr
import warnings
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import pandas as pd 
import seaborn as sns
import cmocean as cmo
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
import matplotlib.ticker as ticker
import matplotlib.gridspec as gridspec
import pandas as pd
from sklearn.cluster import KMeans
from proj_utils import *
from mapping_utils import *
from plotting_utils import *

# %% [markdown]
# ## (1) Open WSC file and SLP

# %%
ds_wsc = xr.open_dataset(data_path + '/wsc.nc')
ds_wsc['longitude'] = ds_wsc.longitude
ds_wsc = rmv_clm(ds_wsc)
ds_wsc = seasonal_detrend(ds_wsc)

# %%
ds_slp = xr.open_dataset(data_path + 'north_atlantic_slp.nc')

ds_slp = ds_slp.sel(expver = slice(0,1)).squeeze()
ds_slp = ds_slp.drop_vars('expver')
ds_slp = ds_slp.sel(time = slice('1993-01-01','2023-12-01'))
ds_slp = ds_slp.sortby(ds_slp.latitude)

ds_slp = seasonal_detrend(ds_slp)

# %%
alt     = pd.read_csv(data_path + 'gsi_altimetry_locations.csv')

# %%
df = pd.read_csv(data_path + 'composite_logs_with_clusters.csv')

# %%
# --- NAO AND EAP SPATIAL PATTERNS FOR WHOLE PERIOD (92-23) ---
nao_sp = xr.open_dataarray(data_path + 'nao_era5_spatial_pattern.nc')
eap_sp = xr.open_dataarray(data_path + 'eap_era5_spatial_pattern.nc')

# %% [markdown]
# ## (2) Calc SLP EOFS (full period) and unscaled PCs

# %%
eofs_full, pcs_full, per_var_full, eigs_full = calc_eofs(ds_slp['msl'], num_modes=4)
# Out:
# /Users/lillienders/gs-var/scripts/proj_utils.py:413: RuntimeWarning: invalid value encountered in sqrt
#   wgts = np.sqrt(coslat)[..., np.newaxis]

# %%
pcs_unscaled = pcs_full*np.sqrt(eigs_full[:4])
nao_unscaled = -pcs_unscaled[:,0]
eap_unscaled = -pcs_unscaled[:,1]

# %%
time_start       = np.arange(np.datetime64('1993-06'), np.datetime64('2018-08'), dtype="datetime64[M]")
time_end         = np.arange(np.datetime64('1997-06'), np.datetime64('2022-08'), dtype="datetime64[M]")

# %%
df['time_start'] = time_start
df['time_end']   = time_end

# %% [markdown]
# ## (3) Do the regressions for each sliding window, and save result

# %%
#window_sz = 48
#with warnings.catch_warnings():
#    warnings.simplefilter("ignore", category=RuntimeWarning)
#    for c in range(0,(len(ds_slp.time)-(window_sz))):
#    #for c in range(1,3):
#        # --- Slice SLP ---
#        slp_temp = ds_slp['msl'].sel(time = slice(ds_slp['msl'].time[c].data, ds_slp['msl'].time[c+window_sz].data))
#
#        # --- Slice WSC --- 
#        wsc_temp = ds_wsc['wsc'].sel(time = slice(ds_wsc['wsc'].time[c].data, ds_wsc['wsc'].time[c+window_sz].data))
#        
#        # --- Calculate modes ---
#        eofs_temp, pcs_temp, per_var_temp, eigs_temp = calc_eofs(slp_temp, num_modes=4)
#        mode_one_temp = eofs_temp[0,:,:]
#        mode_two_temp = eofs_temp[1,:,:]#
#
#        pcs_unscaled = pcs_temp*np.sqrt(eigs_temp[:4])
#        mode_one_unscaled = pcs_unscaled[:,0]
#        mode_two_unscaled = pcs_unscaled[:,1]
#        
#        # --- Correct the sign of the modes ---
#        corr_nao_temp = xr.corr(nao_sp,eofs_temp[0,:,:])
#        corr_eap_temp = xr.corr(nao_sp,eofs_temp[1,:,:])
#        
#        if abs(corr_nao_temp) > abs(corr_eap_temp):
#            sign_nao = xr.corr(nao_sp,eofs_temp[0,:,:])
#            sign_eap = xr.corr(eap_sp,eofs_temp[1,:,:])
#            if sign_nao < 0:
#                mode_one_unscaled = - mode_one_unscaled
#            if sign_eap < 0 :
#                mode_two_unscaled = - mode_two_unscaled
#            reg_nao_wsc_temp   = linregress_spatial(mode_one_unscaled, wsc_temp)
#            reg_eap_wsc_temp   = linregress_spatial(mode_two_unscaled, wsc_temp)
#        else:
#            sign_nao = xr.corr(nao_sp,eofs_temp[1,:,:])
#            sign_eap = xr.corr(eap_sp,eofs_temp[0,:,:])
#            if sign_nao < 0:
#                mode_two_unscaled = - mode_two_unscaled
#            if sign_eap < 0 :
#                mode_one_unscaled = - mode_one_unscaled
#            reg_nao_wsc_temp   = linregress_spatial(mode_two_unscaled, wsc_temp)
#            reg_eap_wsc_temp   = linregress_spatial(mode_one_unscaled, wsc_temp)
#        reg_nao_wsc_temp.to_netcdf(data_path + 'wsc_regressions/nao/' + str(ds_slp.time[c].dt.year.data) + str(ds_slp.time[c].dt.month.data).zfill(2) + '.nc')
#        reg_eap_wsc_temp.to_netcdf(data_path + 'wsc_regressions/eap/' + str(ds_slp.time[c].dt.year.data) + str(ds_slp.time[c].dt.month.data).zfill(2) + '.nc')
#        
#        print(c)

# %%
c       = 0
nao_reg = xr.open_dataset(data_path + 'wsc_regressions/nao/' + str(ds_slp.time[c].dt.year.data) + str(ds_slp.time[c].dt.month.data).zfill(2) + '.nc')
for c in range(1,(len(ds_slp.time)-(window_sz))):
    nao_reg_temp = xr.open_dataset(data_path + 'wsc_regressions/nao/' + str(ds_slp.time[c].dt.year.data) + str(ds_slp.time[c].dt.month.data).zfill(2) + '.nc')
    nao_reg = xr.concat([nao_reg,nao_reg_temp], dim = 'index')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[81], line 5
#       3 for c in range(1,(len(ds_slp.time)-(window_sz))):
#       4     nao_reg_temp = xr.open_dataset(data_path + 'wsc_regressions/nao/' + str(ds_slp.time[c].dt.year.data) + str(ds_slp.time[c].dt.month.data).zfill(2) + '.nc')
# ----> 5     nao_reg = xr.concat([nao_reg,nao_reg_temp], dim = 'index')
#
# File ~/gs-var-env/lib/python3.13/site-packages/xarray/structure/concat.py:277, in concat(objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs, create_index_for_new_dim)
#     264     return _dataarray_concat(
#     265         objs,
#     266         dim=dim,
#    (...)    274         create_index_for_new_dim=create_index_for_new_dim,
#     275     )
#     276 elif isinstance(first_obj, Dataset):
# --> 277     return _dataset_concat(
#     278         objs,
#     279         dim=dim,
#     280         data_vars=data_vars,
#     281         coords=coords,
#     282         compat=compat,
#     283         positions=positions,
#     284         fill_value=fill_value,
#     285         join=join,
#     286         combine_attrs=combine_attrs,
#     287         create_index_for_new_dim=create_index_for_new_dim,
#     288     )
#     289 else:
#     290     raise TypeError(
#     291         "can only concatenate xarray Dataset and DataArray "
#     292         f"objects, got {type(first_obj)}"
#     293     )
#
# File ~/gs-var-env/lib/python3.13/site-packages/xarray/structure/concat.py:676, in _dataset_concat(datasets, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs, create_index_for_new_dim)
#     674         result_vars[k] = v
#     675 else:
# --> 676     combined_var = concat_vars(
#     677         vars, dim_name, positions, combine_attrs=combine_attrs
#     678     )
#     679     # reindex if variable is not present in all datasets
#     680     if len(variable_index) < concat_index_size:
#
# File ~/gs-var-env/lib/python3.13/site-packages/xarray/core/variable.py:3008, in concat(variables, dim, positions, shortcut, combine_attrs)
#    3006     return IndexVariable.concat(variables, dim, positions, shortcut, combine_attrs)
#    3007 else:
# -> 3008     return Variable.concat(variables, dim, positions, shortcut, combine_attrs)
#
# File ~/gs-var-env/lib/python3.13/site-packages/xarray/core/variable.py:1742, in Variable.concat(cls, variables, dim, positions, shortcut, combine_attrs)
#    1740 axis = first_var.get_axis_num(dim)
#    1741 dims = first_var_dims
# -> 1742 data = duck_array_ops.concatenate(arrays, axis=axis)
#    1743 if positions is not None:
#    1744     # TODO: deprecate this option -- we don't need it for groupby
#    1745     # any more.
#    1746     indices = nputils.inverse_permutation(np.concatenate(positions))
#
# File ~/gs-var-env/lib/python3.13/site-packages/xarray/core/duck_array_ops.py:442, in concatenate(arrays, axis)
#     440 xp = get_array_namespace(*arrays)
#     441 if hasattr(xp, "concat"):
# --> 442     return xp.concat(as_shared_dtype(arrays, xp=xp), axis=axis)
#     443 else:
#     444     return xp.concatenate(as_shared_dtype(arrays, xp=xp), axis=axis)
#
# KeyboardInterrupt:

# %%
c       = 0
eap_reg = xr.open_dataset(data_path + 'wsc_regressions/nao/' + str(ds_slp.time[c].dt.year.data) + str(ds_slp.time[c].dt.month.data).zfill(2) + '.nc')
for c in range(1,(len(ds_slp.time)-(window_sz))):
    eap_reg_temp = xr.open_dataset(data_path + 'wsc_regressions/eap/' + str(ds_slp.time[c].dt.year.data) + str(ds_slp.time[c].dt.month.data).zfill(2) + '.nc')
    eap_reg = xr.concat([eap_reg,eap_reg_temp], dim = 'index')

# %%
nao_reg = nao_reg.sel(index = slice(5,-17))
eap_reg = eap_reg.sel(index = slice(5,-17))

# %%
len(df[df['cluster'] == 3])
# Out:
# 29

# %%
nao_reg_c1 = nao_reg.sel(index = df[df['cluster'] == 0].index.to_numpy())
nao_reg_c2 = nao_reg.sel(index = df[df['cluster'] == 1].index.to_numpy())
nao_reg_c3 = nao_reg.sel(index = df[df['cluster'] == 2].index.to_numpy())
nao_reg_c4 = nao_reg.sel(index = df[df['cluster'] == 3].index.to_numpy())

# %%
eap_reg_c1 = eap_reg.sel(index = df[df['cluster'] == 0].index.to_numpy())
eap_reg_c2 = eap_reg.sel(index = df[df['cluster'] == 1].index.to_numpy())
eap_reg_c3 = eap_reg.sel(index = df[df['cluster'] == 2].index.to_numpy())
eap_reg_c4 = eap_reg.sel(index = df[df['cluster'] == 3].index.to_numpy())

# %%
nao_reg_c1_mn = nao_reg_c1.mean(dim = 'index')
nao_reg_c2_mn = nao_reg_c2.mean(dim = 'index')
nao_reg_c3_mn = nao_reg_c3.mean(dim = 'index')
nao_reg_c4_mn = nao_reg_c4.mean(dim = 'index')

# %%
eap_reg_c1_mn = eap_reg_c1.mean(dim = 'index')
eap_reg_c2_mn = eap_reg_c2.mean(dim = 'index')
eap_reg_c3_mn = eap_reg_c3.mean(dim = 'index')
eap_reg_c4_mn = eap_reg_c4.mean(dim = 'index')

# %%
style   = sns.set_style("whitegrid")

fig = plt.figure(figsize=(14, 6))
gs  = gridspec.GridSpec(1, 2, figure=fig)

# -------------------------------------------
# ---- MODE ONE/WSC REGRESSION --------------
# -------------------------------------------
#tit = fig.suptitle('title',fontsize = 18,fontweight = 'bold', y = 0.91)

ax_left = fig.add_subplot(1, 2, 1, projection=ccrs.Orthographic(central_longitude=-40, central_latitude=35))

var_to_plot = nao_reg_c1_mn*100
cmax = 5
var_to_plot.slope.data[var_to_plot.slope.data > cmax] = cmax
var_to_plot.slope.data[var_to_plot.slope.data < -cmax] = -cmax

bbox = [-80, 0, 20, 80]
proj          = ccrs.PlateCarree() # Need to add this to most things as "transform=proj"

fig, ax_left, _ = init_orthomap(bboxplot=bbox, ax=ax_left)
ax_left = add_coast_grid(ax_left, bbox, fill_color='k', line_color='k')

levels = np.linspace(-cmax, cmax, 51)

colorplot = ax_left.contourf(
    var_to_plot.longitude, var_to_plot.latitude, var_to_plot.slope,
    transform=proj, levels=levels, cmap='RdBu_r', zorder=0
)

# -------------------------------------------
# ---- MODE TWO/WSC REGRESSION --------------
# -------------------------------------------

ax_right = fig.add_subplot(1, 2, 2, projection=ccrs.Orthographic(central_longitude=-40, central_latitude=35))

var_to_plot = eap_reg_c1_mn*100
cmax = 5
var_to_plot.slope.data[var_to_plot.slope.data > cmax] = cmax
var_to_plot.slope.data[var_to_plot.slope.data < -cmax] = -cmax

bbox = [-80, 0, 20, 80]
fig, ax_right, _ = init_orthomap(bboxplot=bbox, ax=ax_right)
ax_right = add_coast_grid(ax_right, bbox, fill_color='k', line_color='k')

levels = np.linspace(-cmax, cmax, 51)

colorplot = ax_right.contourf(
    var_to_plot.longitude, var_to_plot.latitude, var_to_plot.slope,
    transform=proj, levels=levels, cmap='RdBu_r', zorder=0
)

cbar = fig.colorbar(
    colorplot, ax=[ax_left, ax_right], fraction=0.05,aspect=50, orientation='horizontal',
    ticks=np.linspace(-5, 5, 11), pad=0.1
)
cbar.ax.tick_params(labelsize=14)
cbar.set_label('Regression Slope [$m^{-1}$]', size=14, labelpad=1)

# %%
style   = sns.set_style("whitegrid")

fig = plt.figure(figsize=(14, 6))
gs  = gridspec.GridSpec(1, 2, figure=fig)

# -------------------------------------------
# ---- MODE ONE/WSC REGRESSION --------------
# -------------------------------------------
#tit = fig.suptitle('title',fontsize = 18,fontweight = 'bold', y = 0.91)

ax_left = fig.add_subplot(1, 2, 1, projection=ccrs.Orthographic(central_longitude=-40, central_latitude=35))

var_to_plot = nao_reg_c2_mn*100
cmax = 5
var_to_plot.slope.data[var_to_plot.slope.data > cmax] = cmax
var_to_plot.slope.data[var_to_plot.slope.data < -cmax] = -cmax

bbox = [-80, 0, 20, 80]
proj          = ccrs.PlateCarree() # Need to add this to most things as "transform=proj"

fig, ax_left, _ = init_orthomap(bboxplot=bbox, ax=ax_left)
ax_left = add_coast_grid(ax_left, bbox, fill_color='k', line_color='k')

levels = np.linspace(-cmax, cmax, 51)

colorplot = ax_left.contourf(
    var_to_plot.longitude, var_to_plot.latitude, var_to_plot.slope,
    transform=proj, levels=levels, cmap='RdBu_r', zorder=0
)

# -------------------------------------------
# ---- MODE TWO/WSC REGRESSION --------------
# -------------------------------------------

ax_right = fig.add_subplot(1, 2, 2, projection=ccrs.Orthographic(central_longitude=-40, central_latitude=35))

var_to_plot = eap_reg_c2_mn*100
cmax = 5
var_to_plot.slope.data[var_to_plot.slope.data > cmax] = cmax
var_to_plot.slope.data[var_to_plot.slope.data < -cmax] = -cmax

bbox = [-80, 0, 20, 80]
fig, ax_right, _ = init_orthomap(bboxplot=bbox, ax=ax_right)
ax_right = add_coast_grid(ax_right, bbox, fill_color='k', line_color='k')

levels = np.linspace(-cmax, cmax, 51)

colorplot = ax_right.contourf(
    var_to_plot.longitude, var_to_plot.latitude, var_to_plot.slope,
    transform=proj, levels=levels, cmap='RdBu_r', zorder=0
)

cbar = fig.colorbar(
    colorplot, ax=[ax_left, ax_right], fraction=0.05,aspect=50, orientation='horizontal',
    ticks=np.linspace(-5, 5, 11), pad=0.1
)
cbar.ax.tick_params(labelsize=14)
cbar.set_label('Regression Slope [$m^{-1}$]', size=14, labelpad=1)

# %%
style   = sns.set_style("whitegrid")

fig = plt.figure(figsize=(14, 6))
gs  = gridspec.GridSpec(1, 2, figure=fig)

# -------------------------------------------
# ---- MODE ONE/WSC REGRESSION --------------
# -------------------------------------------
#tit = fig.suptitle('title',fontsize = 18,fontweight = 'bold', y = 0.91)

ax_left = fig.add_subplot(1, 2, 1, projection=ccrs.Orthographic(central_longitude=-40, central_latitude=35))

var_to_plot = nao_reg_c3_mn*100
cmax = 5
var_to_plot.slope.data[var_to_plot.slope.data > cmax] = cmax
var_to_plot.slope.data[var_to_plot.slope.data < -cmax] = -cmax

bbox = [-80, 0, 20, 80]
proj          = ccrs.PlateCarree() # Need to add this to most things as "transform=proj"

fig, ax_left, _ = init_orthomap(bboxplot=bbox, ax=ax_left)
ax_left = add_coast_grid(ax_left, bbox, fill_color='k', line_color='k')

levels = np.linspace(-cmax, cmax, 51)

colorplot = ax_left.contourf(
    var_to_plot.longitude, var_to_plot.latitude, var_to_plot.slope,
    transform=proj, levels=levels, cmap='RdBu_r', zorder=0
)

# -------------------------------------------
# ---- MODE TWO/WSC REGRESSION --------------
# -------------------------------------------

ax_right = fig.add_subplot(1, 2, 2, projection=ccrs.Orthographic(central_longitude=-40, central_latitude=35))

var_to_plot = eap_reg_c3_mn*100
cmax = 5
var_to_plot.slope.data[var_to_plot.slope.data > cmax] = cmax
var_to_plot.slope.data[var_to_plot.slope.data < -cmax] = -cmax

bbox = [-80, 0, 20, 80]
fig, ax_right, _ = init_orthomap(bboxplot=bbox, ax=ax_right)
ax_right = add_coast_grid(ax_right, bbox, fill_color='k', line_color='k')

levels = np.linspace(-cmax, cmax, 51)

colorplot = ax_right.contourf(
    var_to_plot.longitude, var_to_plot.latitude, var_to_plot.slope,
    transform=proj, levels=levels, cmap='RdBu_r', zorder=0
)

cbar = fig.colorbar(
    colorplot, ax=[ax_left, ax_right], fraction=0.05,aspect=50, orientation='horizontal',
    ticks=np.linspace(-5, 5, 11), pad=0.1
)
cbar.ax.tick_params(labelsize=14)
cbar.set_label('Regression Slope [$m^{-1}$]', size=14, labelpad=1)

# %%
style   = sns.set_style("whitegrid")

fig = plt.figure(figsize=(14, 6))
gs  = gridspec.GridSpec(1, 2, figure=fig)

# -------------------------------------------
# ---- MODE ONE/WSC REGRESSION --------------
# -------------------------------------------
#tit = fig.suptitle('title',fontsize = 18,fontweight = 'bold', y = 0.91)

ax_left = fig.add_subplot(1, 2, 1, projection=ccrs.Orthographic(central_longitude=-40, central_latitude=35))

var_to_plot = nao_reg_c4_mn*100
cmax = 5
var_to_plot.slope.data[var_to_plot.slope.data > cmax] = cmax
var_to_plot.slope.data[var_to_plot.slope.data < -cmax] = -cmax

bbox = [-80, 0, 20, 80]
proj          = ccrs.PlateCarree() # Need to add this to most things as "transform=proj"

fig, ax_left, _ = init_orthomap(bboxplot=bbox, ax=ax_left)
ax_left = add_coast_grid(ax_left, bbox, fill_color='k', line_color='k')

levels = np.linspace(-cmax, cmax, 51)

colorplot = ax_left.contourf(
    var_to_plot.longitude, var_to_plot.latitude, var_to_plot.slope,
    transform=proj, levels=levels, cmap='RdBu_r', zorder=0
)

# -------------------------------------------
# ---- MODE TWO/WSC REGRESSION --------------
# -------------------------------------------

ax_right = fig.add_subplot(1, 2, 2, projection=ccrs.Orthographic(central_longitude=-40, central_latitude=35))

var_to_plot = eap_reg_c4_mn*100
cmax = 5
var_to_plot.slope.data[var_to_plot.slope.data > cmax] = cmax
var_to_plot.slope.data[var_to_plot.slope.data < -cmax] = -cmax

bbox = [-80, 0, 20, 80]
fig, ax_right, _ = init_orthomap(bboxplot=bbox, ax=ax_right)
ax_right = add_coast_grid(ax_right, bbox, fill_color='k', line_color='k')

levels = np.linspace(-cmax, cmax, 51)

colorplot = ax_right.contourf(
    var_to_plot.longitude, var_to_plot.latitude, var_to_plot.slope,
    transform=proj, levels=levels, cmap='RdBu_r', zorder=0
)

cbar = fig.colorbar(
    colorplot, ax=[ax_left, ax_right], fraction=0.05,aspect=50, orientation='horizontal',
    ticks=np.linspace(-5, 5, 11), pad=0.1
)
cbar.ax.tick_params(labelsize=14)
cbar.set_label('Regression Slope [$m^{-1}$]', size=14, labelpad=1)
