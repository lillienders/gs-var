# %%
import netCDF4 as nc
import numpy as np
import xarray as xr
import warnings
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import pandas as pd 
import seaborn as sns
import cmocean as cmo
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
from proj_utils import *

# %% [markdown]
# # Format Paths and Load SSH Fields

# %%
f_path = '/Users/lillienders/Documents/gs_var/data/ssh_fields/'
f_name = 'sla_adt_gs_daily_24.nc'
sla_da = xr.open_dataset(f_path + f_name)
fig_path = '/Users/lillienders/Documents/gs_var/figures/'
gsi_path = '/Users/lillienders/Documents/gs_var/data/gsi/'

# %% [markdown]
# # Do some processing of SSH fields, convert everything to cm

# %%
sla_mo = sla_da.resample(time='1ME').mean() # Calculate Monthly Mean SLA

sla_mo['longitude'] = sla_mo['longitude'] + 360 # Convert to degrees east
sla_mo['adt'] = sla_mo.adt.mean(dim = 'time') # Take time mean average of adt 

sla_mo['adt'] = sla_mo['adt']*100 # Convert to cm
sla_mo['sla'] = sla_mo['sla']*100 # Convert to cm
sla_mo['sla_std'] = sla_mo.sla.std(dim = 'time') # Take std of sla

# %%
sla_mo
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 48, longitude: 120, time: 372)
# Coordinates:
#   * latitude   (latitude) float32 35.12 35.38 35.62 35.88 ... 46.38 46.62 46.88
#   * longitude  (longitude) float32 280.1 280.4 280.6 280.9 ... 309.4 309.6 309.9
#   * time       (time) datetime64[ns] 1993-01-31 1993-02-28 ... 2023-12-31
# Data variables:
#     adt        (latitude, longitude) float32 nan nan nan ... -12.9 -13.35 -13.99
#     err_sla    (time, latitude, longitude) float32 nan nan ... 0.01495 0.01493
#     sla        (time, latitude, longitude) float32 nan nan nan ... 18.99 18.71
#     sla_std    (latitude, longitude) float32 nan nan nan ... 5.66 5.756 5.815
# Attributes:
#     Conventions:       CF-1.11
#     title:             DT merged two satellites Global Ocean Gridded SSALTO/D...
#     institution:       CLS, CNES
#     source:            Altimetry measurements
#     history:           2024/09/23 20:26:01 pva_axp@trex014.sis.cnes.fr Import...
# ...

# %% [markdown]
# # Calc GSI using Max STD Isoline Method

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=DeprecationWarning)
    warnings.simplefilter("ignore", category=RuntimeWarning)
    gsi_lon, gsi_lat, sla_ts, sla_ts_std = gs_index(sla_mo, sla_mo['adt'], alt = True)
# Out:
# 40

# %% [markdown]
# # Plot to Check

# %%
bbox = [280, 304.9, 33.1, 44]
fig = plt.figure(figsize=(14, 8))
crs = ccrs.PlateCarree()
ax = plt.subplot(1, 1, 1, projection=crs)
ax.set_extent(bbox, crs)

ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.LAND, facecolor='k', zorder=1)

gl = ax.gridlines(draw_labels=True, linewidth=0.5, color='gray', linestyle=':')
gl.top_labels = gl.right_labels = False
gl.ylocator = mticker.FixedLocator(np.arange(34,44))
gl.xformatter = LongitudeFormatter(degree_symbol='')
gl.yformatter = LatitudeFormatter(degree_symbol='')

levels = np.linspace(0,42,50)
colorplot = plt.contourf(sla_mo.longitude,sla_mo.latitude,sla_mo.sla_std, levels=levels, cmap='cmo.amp', zorder=0)
plt.contour(sla_mo.longitude,sla_mo.latitude,sla_mo.adt, levels=[40], colors='k', zorder=0)

max_data = int(round(np.nanmax(abs(sla_mo.sla_std)), -1))
colorplot.set_clim(0, max_data)

plt.scatter(gsi_lon, gsi_lat, color='k')

plt.xlabel('Latitude ', fontsize=25)
plt.ylabel('Longitude', fontsize=25)
gl.xlabel_style = {'size': 20}
gl.ylabel_style = {'size': 20}

cbar = plt.colorbar(colorplot, fraction=0.1, pad=0.1, orientation='horizontal',
                    ticks=np.linspace(0, max_data, 11))
cbar.set_label('Standard Deviation of SLA [cm]', size='25', labelpad=25)
cbar.ax.tick_params(labelsize=20)
plt.savefig(fig_path + 'gsi_std_altimetry.png', format='png', bbox_inches="tight",dpi=500)

# %% [markdown]
# # Save GSI Time Series as Data Array

# %%
gsi_array = xr.DataArray(
    data  = sla_ts,
    dims  = ['time'],
    name  = 'gsi',
    coords = dict(
        time = sla_mo.time.data
    ),
    attrs=dict(
        description = 'Gulf Stream Index',
        units = 'cm',
    ),
)
gsi_array.to_netcdf(gsi_path + 'alt_gsi_24.nc')

# %% [markdown]
# # Save GSI Locations as CSV

# %%
gsi_locs = np.stack((gsi_lon, gsi_lat)).T
gsi_locs_df = pd.DataFrame(gsi_locs, columns=['longitude', 'latitude'])
gsi_locs_df.to_csv(gsi_path + 'alt_gsi_locs.csv')
