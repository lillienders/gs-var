# %%
import netCDF4 as nc
import numpy as np
import xarray as xr
import warnings
import metpy.calc as mpcalc
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import pandas as pd 
import seaborn as sns
import cmocean as cmo
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter

# %%
def rmv_clm(dataset):
    """
    Remove climatological mean (i.e., long-term average) from each datavariable in dataset
    Inputs:
    - dataset: xarray dataset, read in from read_file and formated in (time,lat,lon) dimensions
    Outputs:
    - dataset: xarray dataset, formated in (time,lat,lon) dimensions with long-term mean removed
    """
    ds = dataset
    with warnings.catch_warnings():
        warnings.simplefilter("ignore", category=RuntimeWarning)
        for var in list(ds.data_vars):
            ds[var] = ds[var] - ds[var].mean(dim = 'time')
        #ds['sla'] = ds['sla'] - np.nanmean(ds['sla'], axis=0)
    dataset = ds
    return (dataset)

def seasonal_detrend(dataset):
    """
    Remove seasonal cycle (here defined as monthly mean) from time series of each variable
    Inputs:
    - dataset: xarray dataset, read in from read_file and formated in (time,lat,lon) dimensions
    Outputs:
    - dataset: xarray dataset, formated in (time,lat,lon) dimensions with seasonal cycle removed
    """
    ds = dataset
    with warnings.catch_warnings():
        warnings.simplefilter("ignore", category=RuntimeWarning)
        for var in list(ds.data_vars):
            mn_av = np.zeros((12, len(ds.latitude), len(ds.longitude)))
            mn_av[:] = np.nan
            for mn in range(12):
                mn_av[mn, :, :] = np.nanmean(ds[var][mn::12, :, :], axis=0)
            mn_av = np.tile(mn_av, (int(len(ds[var]) / 12), 1, 1))
            detrend_temp = ds[var] - mn_av
            ds[var] = detrend_temp
    dataset = ds
    return (dataset)

def linear_detrend(dataset):
    """
    Remove a linear trend from each grid point
    Inputs:
    - dataset: xarray dataset, read in from read_file and formated in (time,lat,lon) dimensions
    Outputs:
     - dataset: xarray dataset, formated in (time,lat,lon) dimensions with linear trend removed
    """
    ds_temp = dataset
    time_idx = np.linspace(0, len(ds_temp.time) - 1, len(ds_temp.time))
    ds_temp['time'] = time_idx
    ds_poly = ds_temp.polyfit(dim='time', deg=1)
    indices = np.arange(len(ds_temp.time))
    var = 'wsc'
    fit_string = var + '_polyfit_coefficients'
    slope = np.array(ds_poly[fit_string][0]).flatten()
    intercept = np.array(ds_poly[fit_string][1]).flatten()
    lin_fit = np.zeros((len(ds_temp.time), len(slope)))
    for loc in range(len(slope)):
        lin_fit[:, loc] = slope[loc] * indices + intercept[loc]
    lin_fit = np.reshape(lin_fit, (len(ds_temp.time), len(ds_temp.latitude), len(ds_temp.longitude)))
    detrended_series = ds_temp[var] - lin_fit
    dataset[var] = detrended_series
    return (dataset)

# %% [markdown]
# # Sea Level Pressure

# %% [markdown]
# ## Load Raw Data File

# %%
f_path = '/Users/lillienders/Documents/gs_var/data/era_downloads/'
f_name = 'north_atlantic_slp.nc'
slp_da = xr.open_dataset(f_path + f_name)

# %% [markdown]
# ## Process File

# %%
slp_da = slp_da.sel(expver = slice(0,1))
slp_da = slp_da.squeeze()
slp_da = slp_da.drop_vars('expver')
slp_da = slp_da.sel(time = slice('1993-01-01','2023-12-01'))
slp_da = slp_da.sortby(slp_da.latitude)

# %% [markdown]
# ## Deseasonalize and Detrend

# %%
slp_da = rmv_clm(slp_da)
slp_da = seasonal_detrend(slp_da)

# %% [markdown]
# ## Save to NETCDF

# %%
sv_path = '/Users/lillienders/Documents/gs_var/data/climate_fields/'
slp_da.to_netcdf(sv_path + 'slp.nc')

# %% [markdown]
# # Heat Fluxes

# %% [markdown]
# ## Load Raw Data File

# %%
f_path = '/Users/lillienders/Documents/gs_var/data/era_downloads/'
f_name = 'north_atlantic_hf.nc'
hf_da = xr.open_dataset(f_path + f_name)
hf_da = hf_da.squeeze()
hf_da = hf_da.drop_vars(('expver','number'))
hf_da = hf_da.rename({'valid_time':'time'})
hf_da = hf_da.sel(time = slice('1993-01-01','2023-12-01'))
hf_da = hf_da.sortby(hf_da.latitude)

# %%
hf_da = hf_da.rename({'avg_ishf':'sensible_hf','avg_slhtf': 'latent_hf'})

# %%
hf_da = rmv_clm(hf_da)
hf_da = seasonal_detrend(hf_da)

# %%
hf_da.to_netcdf(sv_path + 'heat_flux.nc')

# %% [markdown]
# # Wind Stress

# %% [markdown]
# ## Load Raw Data File

# %%
f_path = '/Users/lillienders/Documents/gs_var/data/era_downloads/'
f_name = 'north_atlantic_ws.nc'
ws_da = xr.open_dataset(f_path + f_name)

# %%
ws_da = ws_da.sel(expver = slice(0,1))
ws_da = ws_da.squeeze()
ws_da = ws_da.drop_vars('expver')
ws_da = ws_da.sel(time = slice('1993-01-01','2023-12-01'))
ws_da = ws_da.sortby(ws_da.latitude)
ws_da = ws_da.sel(latitude = slice(20,80))
ws_da['ewss'] = ws_da['ewss']*3600*100
ws_da['nsss'] = ws_da['nsss']*3600*100

# %%
lsm = ws_da['lsm'].mean(dim ='time') < 0.5
ws_da['ewss'] = ws_da['ewss'].where(lsm, drop=True)
ws_da['nsss'] = ws_da['nsss'].where(lsm, drop=True)

# %%
# Temporarily change units for metpy function compatibility 
ws_da.ewss.attrs['units'] = 'm/s'
ws_da.nsss.attrs['units'] = 'm/s'

# %%
ws_da['wsc'] = mpcalc.vorticity(ws_da['ewss'],ws_da['nsss'])

# %%
ws_da.ewss.attrs['units'] = 'N/m**-2'
ws_da.nsss.attrs['units'] = 'N/m**-2'
ws_da.wsc.attrs ['units'] = ''

# %%
jul_mn = np.nanmean(ws_da['wsc'][0::12, :, :], axis=0)
# Out:
# /var/folders/cc/tkrb8rhn2rdcxs18lry79q580000gn/T/ipykernel_3757/3183040827.py:1: RuntimeWarning: Mean of empty slice
#   jul_mn = np.nanmean(ws_da['wsc'][0::12, :, :], axis=0)

# %%
t = 0
bbox = [270, 350, 20, 80]
fig = plt.figure(figsize=(14, 8))
crs = ccrs.PlateCarree()
ax = plt.subplot(1, 1, 1, projection=crs)
ax.set_extent(bbox, crs)

ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.LAND, facecolor='k', zorder=1)

gl = ax.gridlines(draw_labels=True, linewidth=0.5, color='gray', linestyle=':')
gl.top_labels = gl.right_labels = False
gl.ylocator = mticker.FixedLocator(np.arange(34,44))
gl.xformatter = LongitudeFormatter(degree_symbol='')
gl.yformatter = LatitudeFormatter(degree_symbol='')

max_data = 500*100
levels = np.linspace(-max_data,max_data,50)
colorplot = plt.contourf(ws_da.longitude,ws_da.latitude,jul_mn, levels=levels, cmap='RdBu', zorder=0)
#colorplot.set_clim(-max_data, max_data)

plt.xlabel('Latitude ', fontsize=25)
plt.ylabel('Longitude', fontsize=25)
gl.xlabel_style = {'size': 20}
gl.ylabel_style = {'size': 20}

cbar = plt.colorbar(colorplot, fraction=0.1, pad=0.1, orientation='horizontal',
                    ticks=np.linspace(0, max_data, 11))
cbar.set_label('Standard Deviation [cm]', size='20', labelpad=25)
cbar.ax.tick_params(labelsize=20)
#plt.savefig(fig_path + 'gsi_std_altimetry.png', format='png', bbox_inches="tight",dpi=500)

# %%
ws_da['wsc'] = -ws_da['wsc']

# %%
sv_path = '/Users/lillienders/Documents/gs_var/data/climate_fields/'
ws_da.to_netcdf(sv_path + 'wsc.nc')

# %%
ws_da = rmv_clm(ws_da)

# %%
wsc_anom = xr.apply_ufunc(
    lambda x, mean: x - mean, 
    ws_da.wsc.groupby('time.month'),
    ws_da.wsc.groupby('time.month').mean()
).drop('month')

# %%
ws_da['wsc_anom'] = wsc_anom

# %%
jul_mn = np.nanmean(ws_da['wsc'][0::12, :, :], axis=0)
# Out:
# /var/folders/cc/tkrb8rhn2rdcxs18lry79q580000gn/T/ipykernel_3757/3183040827.py:1: RuntimeWarning: Mean of empty slice
#   jul_mn = np.nanmean(ws_da['wsc'][0::12, :, :], axis=0)

# %%
ws_da.to_netcdf(sv_path + 'wsc_anom.nc')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File /opt/anaconda3/lib/python3.12/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/Users/lillienders/Documents/gs_var/data/climate_fields/wsc_anom.nc',), 'a', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), 'f4a9fde6-5ed4-44b2-bdaf-cacef42d27f3']
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
bbox = [270, 360, 20, 80]
fig = plt.figure(figsize=(14, 8))
crs = ccrs.Robinson(central_longitude=0.)
#plot(projection=ccrs.AlbersEqualArea())

ax = plt.subplot(1, 1, 1, projection=crs)
#ax.set_extent(bbox, crs)

ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.LAND, facecolor='k', zorder=1)

gl = ax.gridlines(draw_labels=True, linewidth=0.5, color='gray', linestyle=':')
gl.top_labels = gl.right_labels = False
gl.xformatter = LongitudeFormatter(degree_symbol='')
gl.yformatter = LatitudeFormatter(degree_symbol='')


plt.xlabel('Latitude ', fontsize=25)
plt.ylabel('Longitude', fontsize=25)
gl.xlabel_style = {'size': 20}
gl.ylabel_style = {'size': 20}

#plt.savefig(fig_path + 'gsi_std_altimetry.png',

# %%
import seaborn as sns
sns.set()
extent = [-100, 20, 0, 70]  # [min_lon, max_lon, min_lat, max_lat]

# Create a plot with the PlateCarree projection
fig, ax = plt.subplots(
    figsize=(10, 8),
    subplot_kw={'projection': ccrs.PlateCarree()}
)
# Set the extent of the map
ax.set_extent(extent, crs=ccrs.PlateCarree())
ax.coastlines(resolution='50m', linewidth=1)
gl = ax.gridlines(draw_labels=True, linewidth=0.5, color='gray', alpha=0.5, linestyle='--')
gl.top_labels = False
gl.right_labels = False
ax.add_feature(cfeature.LAND, edgecolor='k', facecolor='k')

plt.xlabel('Latitude ', fontsize=25)
plt.ylabel('Longitude', fontsize=25)
gl.xlabel_style = {'size': 20}
gl.ylabel_style = {'size': 20}
plt.savefig(fname = 'na',dpi=500)

# %%
f_path = '/Users/lillienders/Documents/gs_var/data/era_downloads/'
f_name = 'north_atlantic_u_250.nc'
u250_da = xr.open_dataset(f_path + f_name)
u250_da = u250_da.squeeze()
u250_da = u250_da.drop_vars(('expver','number'))
u250_da = u250_da.rename({'valid_time':'time'})
u250_da = u250_da.sel(time = slice('1993-01-01','2023-12-01'))
u250_da = u250_da.sortby(u250_da.latitude)
u250_da['longitude'] = u250_da['longitude'] + 360

# %%
u250_da
# Out:
# <xarray.Dataset>
# Dimensions:         (time: 372, latitude: 361, longitude: 321)
# Coordinates:
#   * time            (time) datetime64[ns] 1993-01-01 1993-02-01 ... 2023-12-01
#     pressure_level  float64 250.0
#   * latitude        (latitude) float64 0.0 0.25 0.5 0.75 ... 89.5 89.75 90.0
#   * longitude       (longitude) float64 280.0 280.2 280.5 ... 359.5 359.8 360.0
# Data variables:
#     u               (time, latitude, longitude) float32 ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts

# %%
sv_path = '/Users/lillienders/Documents/gs_var/data/climate_fields/'
u250_da.to_netcdf(sv_path + 'u250.nc')
